# %%
# Ejercicio 1
lista1 = [1, 2, 3, 4, 5]
lista2 = ['a', 'b', 'c', 'd', 'e']

# %%
# !pip install numpy==1.24.3

# %%
# !pip install numpy==1.26.0

# %%
# Ejercicio 2
import pandas as pd

lista_A = [1, 2, 3, 4, 5]
lista_B = ['a', 'b', 'c', 'd', 'e']

datos = {
    'columna_A': lista_A,
    'columna_B': lista_B
}

d_test = pd.DataFrame(datos)
print(d_test)
# Out:
#    columna_A columna_B
# 0          1         a
# 1          2         b
# 2          3         c
# 3          4         d
# 4          5         e

# %%
# Ejercicio 3.1
import pandas as pd

url_hd = 'https://raw.githubusercontent.com/fpineyro/homework-0/master/heart_disease.csv'
d_hd = pd.read_csv(url_hd)
print(d_hd[['age', 'has_heart_disease']])
# Out:
#      age has_heart_disease
# 0     63                no
# 1     67               yes
# 2     67               yes
# 3     37                no
# 4     41                no
# ..   ...               ...
# 298   45               yes
# 299   68               yes
# 300   57               yes
# 301   57               yes
# 302   38                no
#
# [303 rows x 2 columns]

# %%
# Ejercicio 3.2
import pandas as pd
from google.colab import data_table

d_hd = pd.read_csv('https://raw.githubusercontent.com/fpineyro/homework-0/master/heart_disease.csv')
data_table.enable_dataframe_formatter()
d_hd
# Out:
#      age  gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 0     63    male           1                     145                233
# 1     67    male           4                     160                286
# 2     67    male           4                     120                229
# 3     37    male           3                     130                250
# 4     41  female           2                     130                204
# ..   ...     ...         ...                     ...                ...
# 298   45    male           1                     110                264
# 299   68    male           4                     144                193
# 300   57    male           4                     130                131
# 301   57  female           2                     130                236
# 302   38    male           3                     138                175
#
#      fasting_blood_sugar  resting_electro  max_heart_rate  exer_angina  \
# ...

# %%
# Ejercicio 3.3
import pandas as pd
d_hd = pd.read_csv('https://raw.githubusercontent.com/fpineyro/homework-0/master/heart_disease.csv')

print(d_hd.head(3))
print(d_hd.tail(3))
# Out:
#    age gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 0   63   male           1                     145                233
# 1   67   male           4                     160                286
# 2   67   male           4                     120                229
#
#    fasting_blood_sugar  resting_electro  max_heart_rate  exer_angina  oldpeak  \
# 0                    1                2             150            0      2.3
# 1                    0                2             108            1      1.5
# 2                    0                2             129            1      2.6
#
#    slope  num_vessels_flour  thal  heart_disease_severity  exter_angina  \
# 0      3                0.0   6.0                       0             0
# 1      2                3.0   3.0                       2             1
# 2      2                2.0   7.0                       1             1
#
#   has_heart_disease
# 0                no
# 1               yes
# ...

# %%
# Ejercicio 3.4
import pandas as pd

url = "https://raw.githubusercontent.com/fpineyro/homework-0/master/heart_disease.csv"
df = pd.read_csv(url)

columna = df.loc[:, "has_heart_disease"]
print(columna)
# Out:
# 0       no
# 1      yes
# 2      yes
# 3       no
# 4       no
#       ...
# 298    yes
# 299    yes
# 300    yes
# 301    yes
# 302     no
# Name: has_heart_disease, Length: 303, dtype: object

# %%
# Ejercicio 3.5
import pandas as pd

url = "https://raw.githubusercontent.com/fpineyro/homework-0/master/heart_disease.csv"
df = pd.read_csv(url)

columna = df.loc[:, "has_heart_disease"][:3]
print(columna)
# Out:
# 0     no
# 1    yes
# 2    yes
# Name: has_heart_disease, dtype: object

# %%
# Ejercicio 3.6
import pandas as pd

url = "https://raw.githubusercontent.com/fpineyro/homework-0/master/heart_disease.csv"
df = pd.read_csv(url)

subset = df.iloc[0:5, 0:3]
print(subset)
# Out:
#    age  gender  chest_pain
# 0   63    male           1
# 1   67    male           4
# 2   67    male           4
# 3   37    male           3
# 4   41  female           2

# %%
# Ejercicio 4.1
# !pip install funpymodeling

# %%
# Ejercicio 4.2
from funpymodeling.exploratory import status

# %%
# Ejercicio 4.3
import pandas as pd
from funpymodeling.exploratory import status

d_pi = pd.read_csv('https://raw.githubusercontent.com/fpineyro/homework-0/master/heart_disease.csv')
status(d_pi)
# Out:
#                   variable  q_nan     p_nan  q_zeros   p_zeros  unique  \
# 0                      age      0  0.000000        0  0.000000      41
# 1                   gender      0  0.000000        0  0.000000       2
# 2               chest_pain      0  0.000000        0  0.000000       4
# 3   resting_blood_pressure      0  0.000000        0  0.000000      50
# 4        serum_cholestoral      0  0.000000        0  0.000000     152
# 5      fasting_blood_sugar      0  0.000000      258  0.851485       2
# 6          resting_electro      0  0.000000      151  0.498350       3
# 7           max_heart_rate      0  0.000000        0  0.000000      91
# 8              exer_angina      0  0.000000      204  0.673267       2
# 9                  oldpeak      0  0.000000       99  0.326733      40
# 10                   slope      0  0.000000        0  0.000000       3
# 11       num_vessels_flour      4  0.013201      176  0.580858       4
# ...

# %%
# Ejercicio 4.4
import pandas as pd

url = "https://raw.githubusercontent.com/fpineyro/homework-0/master/heart_disease.csv"
df = pd.read_csv(url)

df_thal_nan = df[df["thal"].isna()]
print(df_thal_nan)
# Out:
#      age  gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 87    53  female           3                     128                216
# 266   52    male           4                     128                204
#
#      fasting_blood_sugar  resting_electro  max_heart_rate  exer_angina  \
# 87                     0                2             115            0
# 266                    1                0             156            1
#
#      oldpeak  slope  num_vessels_flour  thal  heart_disease_severity  \
# 87       0.0      1                0.0   NaN                       0
# 266      1.0      2                0.0   NaN                       2
#
#      exter_angina has_heart_disease
# 87              0                no
# 266             1               yes

# %%
# Ejercicio 4.5
d_hd['thal'].fillna(999)
# Out:
# 0      6.0
# 1      3.0
# 2      7.0
# 3      3.0
# 4      3.0
#       ...
# 298    7.0
# 299    7.0
# 300    7.0
# 301    3.0
# 302    3.0
# Name: thal, Length: 303, dtype: float64

# %%
# Ejercicio 4.6
d_hd2 = d_hd.copy()
thal_fill_value = 999
num_vessels_mean = d_hd2['num_vessels_flour'].mean()

d_hd2['thal'] = d_hd2['thal'].fillna(thal_fill_value)
d_hd2['num_vessels_flour'] = d_hd2['num_vessels_flour'].fillna(num_vessels_mean)

# %%
# Ejercicio 4.7
from funpymodeling.exploratory import status
status(d_hd2)
# Out:
#                   variable  q_nan  p_nan  q_zeros   p_zeros  unique     type
# 0                      age      0    0.0        0  0.000000      41    int64
# 1                   gender      0    0.0        0  0.000000       2   object
# 2               chest_pain      0    0.0        0  0.000000       4    int64
# 3   resting_blood_pressure      0    0.0        0  0.000000      50    int64
# 4        serum_cholestoral      0    0.0        0  0.000000     152    int64
# 5      fasting_blood_sugar      0    0.0      258  0.851485       2    int64
# 6          resting_electro      0    0.0      151  0.498350       3    int64
# 7           max_heart_rate      0    0.0        0  0.000000      91    int64
# 8              exer_angina      0    0.0      204  0.673267       2    int64
# 9                  oldpeak      0    0.0       99  0.326733      40  float64
# 10                   slope      0    0.0        0  0.000000       3    int64
# ...

# %%
# Ejercicio 4.8
d_hd.dropna()
# Out:
#      age  gender  chest_pain  resting_blood_pressure  serum_cholestoral  \
# 0     63    male           1                     145                233
# 1     67    male           4                     160                286
# 2     67    male           4                     120                229
# 3     37    male           3                     130                250
# 4     41  female           2                     130                204
# ..   ...     ...         ...                     ...                ...
# 297   57  female           4                     140                241
# 298   45    male           1                     110                264
# 299   68    male           4                     144                193
# 300   57    male           4                     130                131
# 301   57  female           2                     130                236
#
#      fasting_blood_sugar  resting_electro  max_heart_rate  exer_angina  \
# ...
